# %% [markdown]
# # 02 — Exploratory analysis
#
# Check OSM coverage and the Week 2 feature grid after TÜİK areal weighting.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

import geopandas as gpd

grid = gpd.read_parquet(ROOT / "data/processed/cankaya_grid_features.parquet")
print(grid["population_source"].unique())
print("cells", len(grid), "pop sum", float(grid["population"].sum()))
print(grid.groupby("mahalle_name")["population"].sum().sort_values(ascending=False).head(10))
