# %% [markdown]
# # 03 — Feature engineering
#
# 300 m cells, OSM counts, and areal-weighted population. TÜİK mahalle file is optional.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

import geopandas as gpd

grid = gpd.read_parquet(ROOT / "data/processed/cankaya_grid_features.parquet")
print(len(grid), "cells")
print(grid["population_source"].unique())
print(grid["mahalle_name"].nunique(), "mahalle")
grid.drop(columns="geometry").head()
